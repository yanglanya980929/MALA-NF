# %%
# !python -m pip install flowMC
# Out:
# Collecting flowMC
#   Downloading flowMC-0.3.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting jax>=0.4.12 (from flowMC)
#   Using cached jax-0.4.26-py3-none-any.whl.metadata (23 kB)
# Collecting jaxlib>=0.4.12 (from flowMC)
#   Downloading jaxlib-0.4.26-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting equinox>=0.10.6 (from flowMC)
#   Using cached equinox-0.11.4-py3-none-any.whl.metadata (18 kB)
# Collecting optax>=0.1.5 (from flowMC)
#   Using cached optax-0.2.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting evosax>=0.1.4 (from flowMC)
#   Using cached evosax-0.1.6-py3-none-any.whl.metadata (26 kB)
# Collecting tqdm (from flowMC)
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Collecting corner (from flowMC)
#   Downloading corner-2.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting jaxtyping>=0.2.20 (from equinox>=0.10.6->flowMC)
#   Using cached jaxtyping-0.2.28-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./env/lib/python3.10/site-packages (from equinox>=0.10.6->flowMC) (4.11.0)
# Collecting chex (from evosax>=0.1.4->flowMC)
#   Using cached chex-0.1.86-py3-none-any.whl.metadata (17 kB)
# Collecting flax (from evosax>=0.1.4->flowMC)
#   Using cached flax-0.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting numpy (from evosax>=0.1.4->flowMC)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in ./env/lib/python3.10/site-packages (from evosax>=0.1.4->flowMC) (6.0.1)
# Collecting matplotlib (from evosax>=0.1.4->flowMC)
#   Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting dotmap (from evosax>=0.1.4->flowMC)
#   Using cached dotmap-1.3.30-py3-none-any.whl.metadata (3.2 kB)
# Collecting ml-dtypes>=0.2.0 (from jax>=0.4.12->flowMC)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opt-einsum (from jax>=0.4.12->flowMC)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting scipy>=1.9 (from jax>=0.4.12->flowMC)
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.4 MB/s eta 0:00:00
# Collecting absl-py>=0.7.1 (from optax>=0.1.5->flowMC)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting toolz>=0.9.0 (from chex->evosax>=0.1.4->flowMC)
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting typeguard==2.13.3 (from jaxtyping>=0.2.20->equinox>=0.10.6->flowMC)
#   Using cached typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->evosax>=0.1.4->flowMC)
#   Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->evosax>=0.1.4->flowMC)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->evosax>=0.1.4->flowMC)
#   Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 6.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->evosax>=0.1.4->flowMC)
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in ./env/lib/python3.10/site-packages (from matplotlib->evosax>=0.1.4->flowMC) (24.0)
# Collecting pillow>=8 (from matplotlib->evosax>=0.1.4->flowMC)
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->evosax>=0.1.4->flowMC)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./env/lib/python3.10/site-packages (from matplotlib->evosax>=0.1.4->flowMC) (2.9.0.post0)
# Collecting msgpack (from flax->evosax>=0.1.4->flowMC)
#   Downloading msgpack-1.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting orbax-checkpoint (from flax->evosax>=0.1.4->flowMC)
#   Using cached orbax_checkpoint-0.5.9-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorstore (from flax->evosax>=0.1.4->flowMC)
#   Downloading tensorstore-0.1.56-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting rich>=11.1 (from flax->evosax>=0.1.4->flowMC)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->evosax>=0.1.4->flowMC) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1->flax->evosax>=0.1.4->flowMC)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./env/lib/python3.10/site-packages (from rich>=11.1->flax->evosax>=0.1.4->flowMC) (2.17.2)
# Collecting etils[epath,epy] (from orbax-checkpoint->flax->evosax>=0.1.4->flowMC)
#   Downloading etils-1.7.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: nest_asyncio in ./env/lib/python3.10/site-packages (from orbax-checkpoint->flax->evosax>=0.1.4->flowMC) (1.6.0)
# Collecting protobuf (from orbax-checkpoint->flax->evosax>=0.1.4->flowMC)
#   Using cached protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1->flax->evosax>=0.1.4->flowMC)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting fsspec (from etils[epath,epy]->orbax-checkpoint->flax->evosax>=0.1.4->flowMC)
#   Using cached fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting importlib_resources (from etils[epath,epy]->orbax-checkpoint->flax->evosax>=0.1.4->flowMC)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting zipp (from etils[epath,epy]->orbax-checkpoint->flax->evosax>=0.1.4->flowMC)
#   Using cached zipp-3.18.1-py3-none-any.whl.metadata (3.5 kB)
# Downloading flowMC-0.3.1-py3-none-any.whl (35 kB)
# Using cached equinox-0.11.4-py3-none-any.whl (175 kB)
# Using cached evosax-0.1.6-py3-none-any.whl (240 kB)
# Using cached jax-0.4.26-py3-none-any.whl (1.9 MB)
# Downloading jaxlib-0.4.26-cp310-cp310-manylinux2014_x86_64.whl (78.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 MB 55.9 MB/s eta 0:00:000m eta 0:00:010:01:01
# Using cached optax-0.2.2-py3-none-any.whl (223 kB)
# Downloading corner-2.2.2-py3-none-any.whl (15 kB)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached chex-0.1.86-py3-none-any.whl (98 kB)
# Using cached jaxtyping-0.2.28-py3-none-any.whl (40 kB)
# Using cached typeguard-2.13.3-py3-none-any.whl (17 kB)
# Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 112.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 112.6 MB/s eta 0:00:00m eta 0:00:010:0101
# Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 87.4 MB/s eta 0:00:000m eta 0:00:010:00:01
# Using cached dotmap-1.3.30-py3-none-any.whl (11 kB)
# Using cached flax-0.8.2-py3-none-any.whl (686 kB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 17.7 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 89.7 MB/s eta 0:00:000m eta 0:00:01
# Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 85.5 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 101.8 MB/s eta 0:00:00m eta 0:00:01
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached toolz-0.12.1-py3-none-any.whl (56 kB)
# Downloading msgpack-1.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.1/385.1 kB 32.4 MB/s eta 0:00:00
# Using cached orbax_checkpoint-0.5.9-py3-none-any.whl (168 kB)
# Downloading tensorstore-0.1.56-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 103.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading etils-1.7.0-py3-none-any.whl (152 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 kB 13.6 MB/s eta 0:00:00
# Using cached fsspec-2024.3.1-py3-none-any.whl (171 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Installing collected packages: dotmap, zipp, typeguard, tqdm, toolz, pyparsing, protobuf, pillow, numpy, msgpack, mdurl, kiwisolver, importlib_resources, fsspec, fonttools, etils, cycler, absl-py, scipy, opt-einsum, ml-dtypes, markdown-it-py, jaxtyping, contourpy, tensorstore, rich, matplotlib, jaxlib, jax, orbax-checkpoint, equinox, corner, chex, optax, flax, evosax, flowMC
# Successfully installed absl-py-2.1.0 chex-0.1.86 contourpy-1.2.1 corner-2.2.2 cycler-0.12.1 dotmap-1.3.30 equinox-0.11.4 etils-1.7.0 evosax-0.1.6 flax-0.8.2 flowMC-0.3.1 fonttools-4.51.0 fsspec-2024.3.1 importlib_resources-6.4.0 jax-0.4.26 jaxlib-0.4.26 jaxtyping-0.2.28 kiwisolver-1.4.5 markdown-it-py-3.0.0 matplotlib-3.8.4 mdurl-0.1.2 ml-dtypes-0.4.0 msgpack-1.0.8 numpy-1.26.4 opt-einsum-3.3.0 optax-0.2.2 orbax-checkpoint-0.5.9 pillow-10.3.0 protobuf-5.26.1 pyparsing-3.1.2 rich-13.7.1 scipy-1.13.0 tensorstore-0.1.56 toolz-0.12.1 tqdm-4.66.2 typeguard-2.13.3 zipp-3.18.1

# %%
import jax
import jax.numpy as jnp
from flowMC.nfmodel.rqSpline import MaskedCouplingRQSpline
from flowMC.proposal.MALA import MALA
from flowMC.Sampler import Sampler


def log_posterior(x, data: dict):
    return -0.5 * jnp.sum((x - data['data']) ** 2)


data = {'data':jnp.arange(5)}

n_dim = 1
n_chains = 10

rng_key = jax.random.PRNGKey(42)
rng_key, subkey = jax.random.split(rng_key)
initial_position = jax.random.normal(subkey, shape=(n_chains, n_dim)) * 1
rng_key, subkey = jax.random.split(rng_key)
model = MaskedCouplingRQSpline(n_dim, 3, [64, 64], 8, subkey)
step_size = 1e-1
local_sampler = MALA(log_posterior, True, step_size=step_size)

nf_sampler = Sampler(
    n_dim,
    rng_key,
    data,
    local_sampler,
    model,
    n_local_steps=50,
    n_global_steps=50,
    n_epochs=30,
    learning_rate=1e-2,
    batch_size=10000,
    n_chains=n_chains,
)

nf_sampler.sample(initial_position, data)
chains, log_prob, local_accs, global_accs = nf_sampler.get_sampler_state().values()
# Out:
# ['n_dim', 'n_chains', 'n_local_steps', 'n_global_steps', 'n_loop', 'output_thinning', 'verbose']
# Global Tuning:   0%|                                      | 0/3 [00:00<?, ?it/s]
# Compiling MALA body
# Global Tuning: 100%|██████████████████████████████| 3/3 [00:22<00:00,  7.51s/it]
# Global Sampling: 100%|████████████████████████████| 3/3 [00:00<00:00, 61.31it/s]
